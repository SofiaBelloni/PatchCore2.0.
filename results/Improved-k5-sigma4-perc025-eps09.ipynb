# %%
# !pip install wget
import wget
#wget.download("https://raw.githubusercontent.com/DamoFlare/PatchCore2.0/main/ImprovedPatchCore.py")
#wget.download("https://raw.githubusercontent.com/DamoFlare/PatchCore2.0/main/datasetForClip.py")

# %%
# !pip install timm

# %%
! pip install git+https://github.com/openai/CLIP.git

# %%
from torch.utils.data import DataLoader
from ImprovedPatchCore import PatchCoreWithClip
from datasetForClip import MVTecData, POSSIBLE_CLASSES
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
def print_stats(fpr, tpr, roc_auc):
  plt.figure()
  plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC Curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('Curva ROC')
  plt.legend(loc="lower right")
  plt.show()

# %%
total_inference_times = []

# %%
print('-------------DATASET: BOTTLE-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9, perc_coreset=0.01)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('bottle',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: BOTTLE-------------
# Downloading dataset...
# Extracting dataset...
# 100%|██████████| 209/209 [00:15<00:00, 13.41it/s]
# 100%|██████████| 83/83 [00:06<00:00, 13.56it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.014754861234182334

# %%
print('-------------DATASET: CABLE-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('cable',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: CABLE-------------
# 100%|██████████| 224/224 [00:15<00:00, 14.41it/s]
# 100%|██████████| 150/150 [00:17<00:00,  8.73it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04017776012420654

# %%
print('-------------DATASET: CAPSULE-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('capsule',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: CAPSULE-------------
# 100%|██████████| 219/219 [00:14<00:00, 15.24it/s]
# 100%|██████████| 132/132 [00:15<00:00,  8.48it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.03882823026541508

# %%
print('-------------DATASET: CARPET-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('carpet',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: CARPET-------------
# 100%|██████████| 280/280 [00:18<00:00, 14.75it/s]
# 100%|██████████| 117/117 [00:14<00:00,  8.19it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04394903957334339

# %%
print('-------------DATASET: GRID-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('grid',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: GRID-------------
# 100%|██████████| 264/264 [00:09<00:00, 27.11it/s]
# 100%|██████████| 78/78 [00:06<00:00, 11.42it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.034625502733083874

# %%
print('-------------DATASET: LEATHER-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('leather',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: LEATHER-------------
# 100%|██████████| 245/245 [00:14<00:00, 17.46it/s]
# 100%|██████████| 124/124 [00:13<00:00,  8.91it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04041259904061594

# %%
print('-------------DATASET: METAL NUT-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('metal_nut',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: METAL NUT-------------
# 100%|██████████| 220/220 [00:08<00:00, 26.73it/s]
# 100%|██████████| 115/115 [00:07<00:00, 14.92it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.029007465943046238

# %%
print('-------------DATASET: PILL-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('pill',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: PILL-------------
# 100%|██████████| 267/267 [00:11<00:00, 22.32it/s]
# 100%|██████████| 167/167 [00:15<00:00, 11.08it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.03550863123225595

# %%
print('-------------DATASET: SCREW-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('screw',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: SCREW-------------
# 100%|██████████| 320/320 [00:12<00:00, 25.74it/s]
# 100%|██████████| 160/160 [00:13<00:00, 11.59it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.037752507627010344

# %%
print('-------------DATASET: TILE-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('tile',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: TILE-------------
# 100%|██████████| 230/230 [00:11<00:00, 19.96it/s]
# 100%|██████████| 117/117 [00:10<00:00, 10.93it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.03407332632276747

# %%
print('-------------DATASET: TOOTHBRUSH-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('toothbrush',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: TOOTHBRUSH-------------
# 100%|██████████| 60/60 [00:03<00:00, 16.40it/s]
# 100%|██████████| 42/42 [00:03<00:00, 11.97it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.015965473084222703

# %%
print('-------------DATASET: TRANSISTOR-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('transistor',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: TRANSISTOR-------------
# 100%|██████████| 213/213 [00:14<00:00, 14.71it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.43it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.03826397180557251

# %%
print('-------------DATASET: WOOD-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('wood',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: WOOD-------------
# 100%|██████████| 247/247 [00:16<00:00, 14.86it/s]
# 100%|██████████| 79/79 [00:09<00:00,  8.34it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04082219208343119

# %%
print('-------------DATASET: ZIPPER-------------')
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
train_data, test_data = MVTecData('zipper',transform, target_transform).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: ZIPPER-------------
# 100%|██████████| 240/240 [00:09<00:00, 26.38it/s]
# 100%|██████████| 151/151 [00:12<00:00, 12.54it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.03248341036158682

# %%
print(f'Inference time mean: {sum(total_inference_times) / len(total_inference_times)}')
# Out:
# Inference time mean: 0.03404464081648146

# %%
model = PatchCoreWithClip('RN50', k=5, eps=0.9)
transform, target_transform = model.get_transform()
ads = []
ass = []
its = []
for product in POSSIBLE_CLASSES:
  train_data, test_data = MVTecData(product,transform, target_transform).get_datasets()
  train_dataloader = DataLoader(train_data, shuffle=True)
  test_dataloader = DataLoader(test_data, shuffle=False)
  model.fit(train_dataloader)
  roc_auc_ad, roc_auc_as, inference_time = model.evaluate(test_dataloader)
  ads.append(roc_auc_ad)
  ass.append(roc_auc_as)
  its.append(inference_time)
