# %% [markdown]
# # Hyperparameters chosen
# * eps
# * % coreset
# * altro

# %%
# !pip install wget
import wget
wget.download("https://raw.githubusercontent.com/DamoFlare/PatchCore2.0/main/PatchCore.py")
wget.download("https://raw.githubusercontent.com/DamoFlare/PatchCore2.0/main/dataset.py")
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)
# 'dataset (4).py'

# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (0.9.5)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)

# %%
from torch.utils.data import DataLoader
from PatchCore import PatchCore
from dataset import MVTecData, POSSIBLE_CLASSES
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
def print_stats(fpr, tpr, roc_auc):
  plt.figure()
  plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC Curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('Curva ROC')
  plt.legend(loc="lower right")
  plt.show()

# %%
total_inference_times = []

# %%
print('-------------DATASET: BOTTLE-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('bottle',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: BOTTLE-------------
# 100%|██████████| 209/209 [00:14<00:00, 14.67it/s]
# 100%|██████████| 83/83 [00:11<00:00,  6.98it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.05741212454186865

# %%
print('-------------DATASET: CABLE-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('cable',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: CABLE-------------
# 100%|██████████| 224/224 [00:13<00:00, 16.90it/s]
# 100%|██████████| 150/150 [00:18<00:00,  8.06it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.049999578793843584

# %%
print('-------------DATASET: CAPSULE-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('capsule',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: CAPSULE-------------
# 100%|██████████| 219/219 [00:12<00:00, 17.06it/s]
# 100%|██████████| 132/132 [00:15<00:00,  8.29it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04883198304609819

# %%
print('-------------DATASET: CARPET-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('carpet',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: CARPET-------------
# 100%|██████████| 280/280 [00:16<00:00, 17.30it/s]
# 100%|██████████| 117/117 [00:15<00:00,  7.65it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.06096741480705065

# %%
print('-------------DATASET: GRID-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('grid',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: GRID-------------
# 100%|██████████| 264/264 [00:07<00:00, 34.72it/s]
# 100%|██████████| 78/78 [00:07<00:00,  9.85it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.057426996720142856

# %%
print('-------------DATASET: HAZELNUT-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('hazelnut',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: HAZELNUT-------------
# 100%|██████████| 391/391 [00:30<00:00, 12.84it/s]

# %%
print('-------------DATASET: LEATHER-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('leather',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: LEATHER-------------
# 100%|██████████| 245/245 [00:31<00:00,  7.73it/s]
# 100%|██████████| 124/124 [00:15<00:00,  8.13it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.05415526705403482

# %%
print('-------------DATASET: METAL NUT-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('metal_nut',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: METAL NUT-------------
# 100%|██████████| 220/220 [00:06<00:00, 34.86it/s]
# 100%|██████████| 115/115 [00:09<00:00, 11.61it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04832427605338718

# %%
print('-------------DATASET: PILL-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('pill',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: PILL-------------
# 100%|██████████| 267/267 [00:10<00:00, 25.08it/s]
# 100%|██████████| 167/167 [00:17<00:00,  9.28it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.057875323438358876

# %%
print('-------------DATASET: SCREW-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('screw',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: SCREW-------------
# 100%|██████████| 320/320 [00:10<00:00, 31.96it/s]
# 100%|██████████| 160/160 [00:18<00:00,  8.52it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.07154250890016556

# %%
print('-------------DATASET: TILE-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('tile',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: TILE-------------
# 100%|██████████| 230/230 [00:10<00:00, 22.65it/s]
# 100%|██████████| 117/117 [00:12<00:00,  9.69it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.050535120515741855

# %%
print('-------------DATASET: TOOTHBRUSH-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('toothbrush',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: TOOTHBRUSH-------------
# 100%|██████████| 60/60 [00:04<00:00, 14.99it/s]
# 100%|██████████| 42/42 [00:03<00:00, 12.47it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.01890550340924944

# %%
print('-------------DATASET: TRANSISTOR-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('transistor',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: TRANSISTOR-------------
# 100%|██████████| 213/213 [00:12<00:00, 16.49it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.42it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.04885848999023437

# %%
print('-------------DATASET: WOOD-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('wood',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: WOOD-------------
# 100%|██████████| 247/247 [00:14<00:00, 17.07it/s]
# 100%|██████████| 79/79 [00:10<00:00,  7.18it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.05649611617945417

# %%
print('-------------DATASET: ZIPPER-------------')
model = PatchCore('resnet50')
train_data, test_data = MVTecData('zipper',224).get_datasets()
train_dataloader = DataLoader(train_data, shuffle=True)
test_dataloader = DataLoader(test_data, shuffle=False)
model.fit(train_dataloader)
fpr_sm, tpr_sm, fpr_as, tpr_as, roc_auc_as, roc_auc_sm, inference_time = model.evaluate(test_dataloader)
print('Segmentation map (Anomaly segmentation):')
print_stats(fpr_sm, tpr_sm, roc_auc_sm)
print('Anomaly score (Anomaly Detection): ')
print_stats(fpr_as, tpr_as, roc_auc_as)
print(f'Inference Time: {inference_time}')
total_inference_times.append(inference_time)
# Out:
# -------------DATASET: ZIPPER-------------
# 100%|██████████| 240/240 [00:08<00:00, 27.79it/s]
# 100%|██████████| 151/151 [00:14<00:00, 10.37it/s]
# Segmentation map (Anomaly segmentation):
# Anomaly score (Anomaly Detection):
# Inference Time: 0.052556369478339394

# %%
print(f'Inference time mean: {sum(total_inference_times) / len(total_inference_times)}')
# Out:
# Inference time mean: 0.05102766389099619

# %%
model = PatchCore('resnet50')
ads = []
ass = []
its = []
for product in POSSIBLE_CLASSES:
  train_data, test_data = MVTecData(product,224).get_datasets()
  train_dataloader = DataLoader(train_data, shuffle=True)
  test_dataloader = DataLoader(test_data, shuffle=False)
  model.fit(train_dataloader)
  roc_auc_ad, roc_auc_as, inference_time = model.evaluate(test_dataloader)
  ads.append(roc_auc_ad)
  ass.append(roc_auc_as)
  its.append(inference_time)
# Out:
# 100%|██████████| 209/209 [00:08<00:00, 25.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5dd7743ff44c> in <cell line: 5>()
#       7   train_dataloader = DataLoader(train_data, shuffle=True)
#       8   test_dataloader = DataLoader(test_data, shuffle=False)
# ----> 9   model.fit(train_dataloader)
#      10   roc_auc_ad, roc_auc_as, inference_time = model.evaluate(test_dataloader)
#      11   ads.append(roc_auc_ad)
#
# /content/PatchCore.py in fit(self, input)
#      60     except ValueError:
#      61       print(f'Error in SparseRandomProjection')
# ---> 62     self.memory_bank = patches[self.coreset_reduction(reduced_patches)]
#      63
#      64   def predict(self, sample):
#
# /content/PatchCore.py in coreset_reduction(self, patches)
#     136       last_item = patches[index : index + 1]
#     137       min_distances[index] = 0
# --> 138       coreset_indexes.append(index)
#     139     return coreset_indexes
#     140
#
# KeyboardInterrupt:

# %%
import numpy as np

# %%
with open('anomaly_detection-k3-cr025-eps09.npy', 'wb') as f:
  np.save(f, ads.numpy())
with open('anomaly_segmentation-k3-cr025-eps09.npy', 'wb') as f:
  np.save(f, ass.numpy())
with open('inference_times-k3-cr025-eps09.npy', 'wb') as f:
  np.save(f, its.numpy())

# %% [markdown]
# #Preprocessing

# %%
(x_train_orig, y_train), (x_test_orig, y_test) = tf.keras.datasets.mnist.load_data()
